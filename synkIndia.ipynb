# %%
# %pip install -q openai-whisper deep-translator gTTS streamlit librosa opencv-python torchaudio

# !apt-get install -y ffmpeg

import os
os.makedirs("data/raw", exist_ok=True)
os.makedirs("data/processed", exist_ok=True)
os.makedirs("src", exist_ok=True)

print("✅ Workspace initialized and libraries installed successfully!")
